# %%
x=10
name='Alice'
print(x)
print('x')
print (name)
# Out:
# 10
# x
# Alice

# %%
print("name of the student is", name )
# Out:
# name of the student is Alice

# %%
name1="Alice"
name2="Kevin"
print(name2)
# Out:
# Kevin

# %%
name_3="henry"
print(name_3)
# Out:
# henry

# %%
_4name='Kayla'
print(_4name)

# %%
x,y,z=10,name,30
print(x,y,z)
# Out:
# 10 Alice 30

# %%
p=q=r=10
x,y,z='Alice','Henry','Kaylah'
print(x,y,z)
# Out:
# Alice Henry Kaylah

# %%
x=10
type(x)
# Out:
# int

# %%
range=(1,50)
print(range)
# Out:
# (1, 50)
